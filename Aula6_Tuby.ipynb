# %%
import matplotlib.pyplot as plt
import numpy as np

def retas_paralelas():
    x1=np.arange(10, 90, 20)
    x2=np.arange(20, 100, 20)

    y1=np.array(x1)/100

    plt.plot(x1,y1)
    plt.plot(x1,y1, 'go')
    plt.plot(x2,y1)
    plt.plot(x2,y1, 'ro')

    plt.show()
    
def retas_concorrentes():
    x1=np.arange(10, 90, 20)
    x2=np.arange(80, 0, -20)

    y1=np.array(x1)/100

    plt.plot(x1,y1)
    plt.plot(x1,y1, 'go')
    plt.plot(x2,y1)
    plt.plot(x2,y1, 'ro')

    plt.show()
    
def retas():
    x1=np.linspace(10,40,4)
    y1=np.array(x1)/100
    
    x2=x1
    y2=y1
    
    plt.plot(x1,y1)
    plt.plot(x1,y1, 'go')
    plt.plot(x2,y2)
    plt.plot(x1,y1, 'ro')
    
    plt.show()
    
retas_paralelas()
retas_concorrentes()
retas()

# %%
import matplotlib.pyplot as plt
import numpy as np



x1=np.arange(-10, 10, 1)

y1=np.array(3-(2*x1))
y2=np.array((-2-(x1))/-3)

plt.plot(x1,y1)
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x1=np.arange(-10, 10, 1)

y1=np.array(9-(x1)*3)
y2=np.array(8-(x1)/2)

plt.plot(x1,y1)
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y2)

plt.show()


a=np.array([[3,1], [1,2]])
b=np.array([9,8])
x=np.linalg.solve(a,b)
print(x)
# Out:
# [ 2.  3.]

# %%
import matplotlib.pyplot as plt
import numpy as np


x1=np.arange(-10, 10, 1)

y1=np.array(3-(x1)*2)
y2=np.array(6-(x1)*4)/2

plt.plot(x1,y1)
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x1=np.arange(-10, 10, 1)

y1=np.array(3-(x1)*2)
y2=np.array(2-(x1)*4)/2

plt.plot(x1,y1)
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x1=np.arange(0, 3, 1)

y1=np.array((x1))
y2=np.array((x1)*(2)-1)

plt.plot(x1,y1)
plt.plot(x1,y2)

A  = np.matrix([[2, 1], [1, -3]])

v = np.array([1, 1])
u = np.matmul(A.data, v)

v1=np.array([2, -1])
u1=np.matmul(A.data, v1)

plt.show()


x1=np.arange(-1, 6, 1)
y1=np.array(u[0]-(x1)*u[1])
y2=np.array(u1[0]-(x1)*u1[1])

plt.plot(x1,y1)
plt.plot(x1,y2)

plt.show()
